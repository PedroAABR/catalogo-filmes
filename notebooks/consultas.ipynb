# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroAABR/sql-filmes/blob/main/consultas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install psycopg2-binary sqlalchemy

from sqlalchemy import create_engine
import pandas as pd

# Substitua "seu_banco" pelo nome exato do seu banco no Supabase
uri = "postgresql://postgres.gebifkvqewuhyeulnteb:dvn1JigWjTGLrlEW@aws-0-sa-east-1.pooler.supabase.com:5432/postgres?sslmode=require"

# Criando a conexão
engine = create_engine(uri)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 21.7 MB/s eta 0:00:00
# ...

# %%
# O SELECT * busca todas as colunas da tabela filmes.
query = "SELECT * FROM filmes;"
df = pd.read_sql_query(query, engine)
df
# Out:
#    id                titulo               diretor  ano_lancamento  \
# 0   1     O Poderoso Chefão  Francis Ford Coppola            1972
# 1   2         Clube da Luta         David Fincher            1999
# 2   3  Vingadores: Ultimato         Anthony Russo            2019
# 3   4                Matrix        Lana Wachowski            1999
# 4   5          Interestelar     Christopher Nolan            2014
# 5   6              A Origem     Christopher Nolan            2010
# 6   7              Parasita          Bong Joon-ho            2019
#
#               genero  nota_imdb
# 0              Drama        9.2
# 1              Drama        8.8
# 2               Ação        8.4
# 3  Ficção Científica        8.7
# 4  Ficção Científica        8.6
# 5               Ação        8.8
# 6           Suspense        8.6

# %%
# Utiliza WHERE para filtrar registros. Aqui, buscamos apenas os filmes lançados após 2010.
query = "SELECT * FROM filmes WHERE ano_lancamento > 2010;"
df = pd.read_sql_query(query, engine)
df
# Out:
#    id                titulo            diretor  ano_lancamento  \
# 0   3  Vingadores: Ultimato      Anthony Russo            2019
# 1   5          Interestelar  Christopher Nolan            2014
# 2   7              Parasita       Bong Joon-ho            2019
#
#               genero  nota_imdb
# 0               Ação        8.4
# 1  Ficção Científica        8.6
# 2           Suspense        8.6

# %%
# Filtra pelo nome do diretor e mostra só título e ano.
query = """
SELECT titulo, ano_lancamento
FROM filmes
WHERE diretor = 'Christopher Nolan';
"""
df = pd.read_sql_query(query, engine)
df
# Out:
#          titulo  ano_lancamento
# 0  Interestelar            2014
# 1      A Origem            2010

# %%
# ORDER BY ordena os filmes com base na nota, do maior para o menor (DESC).
query = "SELECT titulo, nota_imdb FROM filmes ORDER BY nota_imdb DESC;"
df = pd.read_sql_query(query, engine)
df
# Out:
#                  titulo  nota_imdb
# 0     O Poderoso Chefão        9.2
# 1         Clube da Luta        8.8
# 2              A Origem        8.8
# 3                Matrix        8.7
# 4          Interestelar        8.6
# 5              Parasita        8.6
# 6  Vingadores: Ultimato        8.4

# %%
# Combinamos duas condições com AND.
query = """
SELECT titulo, nota_imdb
FROM filmes
WHERE genero = 'Drama' AND nota_imdb > 8.5;
"""
df = pd.read_sql_query(query, engine)
df
# Out:
#               titulo  nota_imdb
# 0  O Poderoso Chefão        9.2
# 1      Clube da Luta        8.8

# %%
# Criar o conteúdo .sql (DDL + DML)
sql_script = """
-- Criação da tabela de filmes
CREATE TABLE filmes (
    id SERIAL PRIMARY KEY,
    titulo VARCHAR(100),
    diretor VARCHAR(100),
    ano_lancamento INT,
    genero VARCHAR(50),
    nota_imdb DECIMAL(3,1)
);

-- Inserção de dados na tabela de filmes
INSERT INTO filmes (titulo, diretor, ano_lancamento, genero, nota_imdb) VALUES
('O Poderoso Chefão', 'Francis Ford Coppola', 1972, 'Drama', 9.2),
('Clube da Luta', 'David Fincher', 1999, 'Drama', 8.8),
('Vingadores: Ultimato', 'Anthony Russo', 2019, 'Ação', 8.4),
('Matrix', 'Lana Wachowski', 1999, 'Ficção Científica', 8.7),
('Interestelar', 'Christopher Nolan', 2014, 'Ficção Científica', 8.6),
('A Origem', 'Christopher Nolan', 2010, 'Ação', 8.8),
('Parasita', 'Bong Joon-ho', 2019, 'Suspense', 8.6);
"""

# %%
# Salvar como arquivo .sql
with open("script_filmes.sql", "w") as file:
    file.write(sql_script)

# %%
# Baixar o arquivo .sql para o seu computador
from google.colab import files
files.download("script_filmes.sql")
